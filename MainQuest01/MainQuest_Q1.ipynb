# %% [markdown]
# <a href="https://colab.research.google.com/github/thetjswo/Aiffel_Quest/blob/master/MainQuest01/MainQuest_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬 모듈 메인 퀘스트
#
# ## 문제
# ![스크린샷 2023-11-17 오후 12.16.42.png](data:image/png;base64,...)
#
# ![스크린샷 2023-11-17 오후 12.17.33.png](data:image/png;base64,...)

# %% [markdown]
# ### Q1. Account 클래스 : 은행에 가서 계좌를 개설하면 은행 이름, 예즘주, 계좌번호, 잔액이 설정됩니다. Account 클래스를 생성한 후, 생성자를 구현해 보세요. 생성자에는 초기 잔액만 입력 받습니다. 은행 이름은 SC은행으로 계좌번호는 3자리-3자리-6자리 형태로 랜덤하게 생성됩니다. (은행이름: SC은행, 계좌번호: 111-11-111111)
#
#
# > #### 고려했던 사항
# * 은행 이름은 고정되어야 한다.
#   * 클래스 변수 사용
# * 예금주의 이름과 잔액은 사용자로부터 매개변수로 넘겨 받아야 한다.
#   * name과 bal 매개변수 사용
# * 계좌번호는 랜덤 값으로 생성하되 각 자리수가 '-'로 구분되어야 한다.
#   * random 모듈 사용
#   * str()함수와 insert()함수 사용

# %%
from random import *

class Account:
    # 은행이름 SC은행으로 고정
    bank = 'SC은행'

    # 예금주, 초기 잔액 입력
    def __init__(self, name, bal):
        # 예금주 속성
        self.name = name
        # 잔액 속성
        self.bal = bal

        # 계좌번호 빈 값 생성
        self.acc_num = ''
        # 랜덤한 정수 11자리 리스트 생성
        rd = [str(randint(0, 10)) for i in range(11)]
        # 3번째와 6번째 자리에 '-' 추가
        rd.insert(3, '-')
        rd.insert(6, '-')

        # 인덱스 순서대로 계좌번호 속성에 값 추가
        for i in rd:
            self.acc_num += i

# %% [markdown]
# ### Q2. 클래스 변수: 클래스 변수를 사용해서 Account 클래스로부터 생성된 계좌 객체의 개수를 저장하세요.
#
#
# #### 고려했던 사항
# * 객체 갯수는 객체 외부에 있어야 한다.
#   * 생성자 외부에 클래스 변수로 선언
#   * 모든 객체가 접근할 수 있도록 해야하기에 self 사용 안함
# * 객체 갯수는 특정 시점에 증가하여야 한다.
#   * 생성자가 호출되는 시점에 객체 갯수 증가

# %%
class Account:
    # 생성된 계좌 개수
    acc_cnt = 0

    def __init__(self, name, bal):

      #객체 생성 시, 계좌 개수 +1
      Account.acc_cnt += 1

# %% [markdown]
# ### Q3. 클래스 변수 출력 : Account 클래스로부터 생성된 계좌의 개수를 출력하는 get_account_num() 메서드를 추가하세요.
#
# #### 고려했던 사항
# * acc_cnt 변수를 적절하게 사용해야 한다.
#   * 습관적인 self가 아닌 클래스 변수로 접근
#
#
# ---
# ```
# 생성된 계좌의 개수는 4개 입니다.
# ```

# %%
# 생성된 계좌 개수 출력 메서드
def get_account_num(self):
    return print(f'생성된 계좌의 개수는 {Account.acc_cnt}개 입니다.')


client_a = Account('이선재', 0)
client_a.get_account_num()

# %% [markdown]
# ### Q4. 입금 메서드 : Account 클래스에 입금을 위한 deposit 메서드를 추가하세요. 입금인 최소 1원만 가능합니다.
#
#
# #### 고려했던 사항
# * 입금 금액이 0이면 다시 입력을 받아야 한다.
#   * while 반복문으로 입금 금액이 0인 경우 재입력 유도
# * 입금 금액은 정수로 받아야 한다.
#   * try - except 구문으로 문자 입력 시, 재입력 유도
# * 입금금액은 계좌 잔액에 추가되어야 한다.
#   * 계좌 잔액 += 입금 금액
#
# ---
# ```
# 입금할 금액을 입력하세요: 입금 금액 입력은 숫자만 가능합니다.
# 처리가 완료되었습니다.
# 이선재님의 잔고는 1.0원 입니다.
# ```

# %%
# 예금 입금 메서드
def deposit(self):
    # 초기 예금 값 0으로 초기화
    self.dps_money = 0

    try:
        # 입력한 예금이 0이 아닐 때까지 반복
        while self.dps_money == 0:
            # 입력한 예금을 정수형으로 캐스팅
            self.dps_money = int(input('입금할 금액을 입력하세요: '))

            # 입력한 예금이 0일 경우 재입력 유도
            if self.dps_money == 0:
                print('계좌 입금은 1원 이상부터 가능합니다.')
            else:
                # 예금을 잔고에 추가
                self.bal += self.dps_money

            # 처리 결과 출력
        print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

        return True
    except:
        # 문자형이 입력되었을 때 안내 출력
        print('입금 금액 입력은 숫자만 가능합니다.')

        return False



# 계좌 입금 함수 정의
def deposit(client):
    # 정상 입력 여부 boolean 초기화
    dps_success = False
    # 처리 결과로 True가 반환될 때까지 반복
    while dps_success == False:
        if client.deposit():
            dps_success = True

            break
        else:
            continue

client_a = Account('이선재', 0)
deposit(client_a)

# %% [markdown]
# ### Q5. 출금 메서드 : Account 클래스에 출금을 위한 withdraw 메서드를 추가하세요, 출금은 계좌의 잔고 이상으로 출금할 수는 없습니다.
#
# #### 고려했던 사항
# * 계좌 잔고 이상의 출금을 막는 조건문을 만들어야 한다.
#   * 객체의 잔고 속성과 비교하여 조건문 생성
# * 예금 출금은 정수형으로 받아야 한다.
#   * try - except 구문으로 정수 입력 유도
# * 출금된 금액만큼 잔고에서 차감되어야 한다.
#   * 계좌 잔액 -= 출금액
#
# ---
# ```
# 출금할 금액을 입력하세요: d
# 입금 금액 입력은 숫자만 가능합니다.
# 출금할 금액을 입력하세요: 1
# 처리가 완료되었습니다.
# 이선재님의 잔고는 5.05원 입니다.
# ```

# %%
# 출금 메서드 정의
def withdraw(self):

    # 출금 금액을 잔고보다 1 크게 초기화
    self.wd_money = self.bal + 1

    try:
        # 출금액이 잔고보다 작을 때까지 반복
        while self.wd_money > self.bal:
            self.wd_money = int(input('출금할 금액을 입력하세요: '))

            # 출금액이 잔고보다 클 경우, 재입력 유도
            if self.wd_money > self.bal:
                print(f'''계좌 출금은 잔액을 상회할 수 없습니다.
현재 {self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')
            else:
                # 잔고에서 출금액 차감
                self.bal -= self.wd_money

        # 처리 결과 안내
        print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

        return True
    except:
        # 문자 입력 시, 정수 입력 유도
        print('입금 금액 입력은 숫자만 가능합니다.')

        return False


# 계좌 출금 함수 정의
def withdraw(client):
    # 정상 입력 여부 boolean 초기화
    wd_success = False
    # 처리 결과가 True일 때까지 반복
    while wd_success == False:
        if client.withdraw():
            wd_success = True

            break
        else:
            continue

client_a = Account('이선재', 100000)
deposit(client_a)

# %% [markdown]
# ### Q6. 정보 출력 메서드 : Account 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 잔고는 세자리마다 쉼표를 출력하세요. (은행이름: SC은행, 예금주: 파이썬, 계좌번호: 111-11-111111, 잔고: 10,000원)
#
# #### 고려했던 사항
# * 정보 별로 사용하는 방법의 차이를 고려해야 한다.
#   * 클래스 변수와 객체의 속성을 잘 구분하여 출력
# * 금액을 세자리마다 ,로 구분을 해야 한다.
#   * format()함수 사용
#
# ---
# ```
# 개설된 계좌 정보 : (은행이름: SC은행, 예금주: 이창재), 계좌번호: 775-70-525884, 잔고: 10,000,000
# ```

# %%
def display_info(self):
    return print(f"개설된 계좌 정보 : (은행이름: {Account.bank}, 예금주: {self.name}), 계좌번호: {self.acc_num}, 잔고: {format(self.bal, ',')}")

# %% [markdown]
# ### Q7. 이자 지급하기. 입금 횟수가 5회가 될 때 잔고를 기준으로 1%의 이자가 잔고에 추가되도록 코드를 변경해보세요.
#
# #### 고려했던 사항
# * 입금 횟수가 5의 배수가 될 때마다 이자를 지급해야 한다.
#   * 입금 카운드 변수를 생성하여 입금이 완료된 시점에 1씩 증가 시킴
#   * 입금 카운크가 5의 배수일 경우 이자 계산
# * 이자율을 계산하는 연산식을 사용해야 한다.
#   * 이자 = 원금 * 0.01
#   * 잔고 += 이자
#
#
# ---
# ```
# 입금할 금액을 입력하세요: 100
# 처리가 완료되었습니다.
# 이선재님의 잔고는 100원 입니다.
# 입금할 금액을 입력하세요: 100
# 처리가 완료되었습니다.
# 이선재님의 잔고는 200원 입니다.
# 입금할 금액을 입력하세요: 100
# 처리가 완료되었습니다.
# 이선재님의 잔고는 300원 입니다.
# 입금할 금액을 입력하세요: 100
# 처리가 완료되었습니다.
# 이선재님의 잔고는 400원 입니다.
# 입금할 금액을 입력하세요: 100
# 처리가 완료되었습니다.
# 이선재님의 잔고는 505.0원 입니다.
# ```

# %%
# 예금 입금 메서드
def deposit(self):
    # 초기 예금 값 0으로 초기화
    self.dps_money = 0

    try:
        # 입력한 예금이 0이 아닐 때까지 반복
        while self.dps_money == 0:
            # 입력한 예금을 정수형으로 캐스팅
            self.dps_money = int(input('입금할 금액을 입력하세요: '))

            # 입력한 예금이 0일 경우 재입력 유도
            if self.dps_money == 0:
                print('계좌 입금은 1원 이상부터 가능합니다.')
            else:
                # 예금을 잔고에 추가
                self.bal += self.dps_money
                # 입금이 완료된 시점에 입금 횟수 카운트
                self.dps_cnt += 1

        # 입금 카운드가 5의 배수일 경우 이자 계산
        if self.dps_cnt % 5 == 0:
          # 이자 = 원금의 1%
          interest = self.bal * 0.01
          # 원금에 이자 추가
          self.bal += interest

        # 처리 결과 출력
        print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

        return True
    except:
        # 문자형이 입력되었을 때 안내 출력
        print('입금 금액 입력은 숫자만 가능합니다.')

        return False



# 계좌 입금 함수 정의
def deposit(client):
    # 정상 입력 여부 boolean 초기화
    dps_success = False
    # 처리 결과로 True가 반환될 때까지 반복
    while dps_success == False:
        if client.deposit():
            dps_success = True

            break
        else:
            continue

client_a = Account('이선재', 0)
deposit(client_a)

# %% [markdown]
# ### Q8. 여러 객체 생성 Account 클래스로부터 3개 이상 인스턴스를 생성하고 생성된 인스턴스를 리스트에 저장해보세요.
#
# #### 고려했던 사항
# * 각각의 객체를 3개 이상 만들어야 한다.
#   * 각각의 예금주명과 초기 원금을 가진 4개의 객체 생성
# * 생성한 객체를 리스트에 담아야 한다.
#   * 생성한 객체를 고객 리스트에 추가

# %%
# 4개의 객체 생성
client_a = Account('이선재', 0)
client_b = Account('이창재', 10000000)
client_c = Account('이봉재', 20000)
client_d = Account('이현재', 5000)

# 4개의 객체를 가진 고객 리스트 생성
client = [client_a, client_b, client_c, client_d]

# %% [markdown]
# ### Q9. 객체 순회 반복문을 통해 리스트에 있는 객체를 순회하면서 잔고가 100만원 이상인 고객의 정보만 출력하세요.
#
# #### 고려했던 사항
# * 리스트의 객체를 순차적으로 돌려 고객 정보를 조회해야 한다.
#   * for문을 사용하여 객체 별로 display_info() 메서드 호출
# * 조회한 정보에서 잔액이 100만원 이상인 고객을 추출해야 한다.
#   * 객체의 잔고 속성을 사용하여 100만원 이상인 고객 정보 추출
#
#
# ---
# ```
# 계좌 잔고가 100만원 이상인 고객 정보를 탐색합니다.
# **********************************************************************
# 개설된 계좌 정보 : (은행이름: SC은행, 예금주: 이선재), 계좌번호: 603-32-473434, 잔고: 6,000,000.0
# 개설된 계좌 정보 : (은행이름: SC은행, 예금주: 이창재), 계좌번호: 5104-96-1091066, 잔고: 10,000,000
# **********************************************************************
# ```

# %%
# 100만워 이상 예금한 고객 조회 함수 정의
def vip(client):
    print('계좌 잔고가 100만원 이상인 고객 정보를 탐색합니다.')
    print('*'*70)
    # 반복문으로 객체별 정보 조회
    for i in client:
        # 잔고 속성이 1000000 이상인 고객 조회
        if i.bal > 1000000:
            # 계좌 정보 확인
            i.display_info()

    print('*' * 70)

# VIP 고객 정보 출력 함수 호출
vip(client)

# %% [markdown]
# ### Q10. 입출금 내역. 입금과 출금 내역이 기록되도록 코드를 업데이트 하세요. 입금 내역과 출금 내역을 출력하는 deposit_history와 withdraw_history 메서드를 추가하세요.
#
#
# #### 고려했던 사항
# * 입금 내역과 출금내역 리스트를 생성해야 한다.
#   * 객체 속성으로 입금내역 리스트, 출금 내역 리스트를 생성
# * 입/출금이 완료된 시점에 각 내역이 리스트에 들어가야 한다.
#   * 입/출금이 완료된 직후 리스트에 내역을 추가
# * 입/출금 시간 정보가 들어가야 한다.
#   * datatime 모듈 사용
#   * 입/출근 이력 앞에 년도-월-일 시:분:초 정보를 붙여 리스트에 추가
# * 각 객체가 입/출금 내역을 확인할 수 있어야 한다.
#   * 각각의 메서드를 정의하여 객체가 접근할 수 있도록 코딩
#
#
# ---
# ```
# ***이선재님의 예금 입금 이력 리스트를 출력합니다.***
# 2023-11-17 13:29:16, 1,000,000원 예금 입금
# 2023-11-17 13:29:19, 1,000,000원 예금 입금
# 2023-11-17 13:29:20, 1,000,000원 예금 입금
# 2023-11-17 13:29:21, 1,000,000원 예금 입금
# 2023-11-17 13:29:22, 1,000,000원 예금 입금
# 2023-11-17 13:29:22, 1,000,000원 이자 입금
# 2023-11-17 13:29:23, 1,000,000원 예금 입금
# ```
# ```
# ***이선재님의 예금 출금 이력 리스트를 출력합니다.***
# 2023-11-17 13:29:25, 50,000원 예금 출금
# ```

# %%
# 입금 메서드 정의
    def deposit(self):
        # 입금 시간 구하기
        d = datetime.datetime.now()

        self.dps_money = 0

        try:
            while self.dps_money == 0:
                self.dps_money = int(input('입금할 금액을 입력하세요: '))

                if self.dps_money == 0:
                    print('계좌 입금은 1원 이상부터 가능합니다.')
                else:
                    self.bal += self.dps_money
                    self.dps_list.append(f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.dps_money, ",")}원 예금 입금')
                    # 입금 횟수 카운트
                    self.dps_cnt += 1

            # 입금 횟수가 5의 배수가 되면 이자 추가
            if self.dps_cnt % 5 == 0:
                # 이자 = 원금의 1%
                interest = self.bal * 0.01
                self.bal += interest

                # 입금 시간을 포함한 입금 이력을 리스트에 추가
                self.dps_list.append(
                    f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.dps_money, ",")}원 이자 입금')

            print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

            return True
        except:
            print('입금 금액 입력은 숫자만 가능합니다.')

            return False


    # 출금 메서드 정의
    def withdraw(self):
        # 출금 시간 구하기
        d = datetime.datetime.now()

        self.wd_money = self.bal + 1

        try:
            while self.wd_money > self.bal:
                self.wd_money = int(input('출금할 금액을 입력하세요: '))

                if self.wd_money > self.bal:
                    print(f'''계좌 출금은 잔액을 상회할 수 없습니다.
현재 {self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')
                else:
                    self.bal -= self.wd_money
                    # 출금 시간을 포함한 출금 이력을 리스트에 추가
                    self.wd_list.append(
                        f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.wd_money, ",")}원 예금 출금')

            print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

            return True
        except:
            print('입금 금액 입력은 숫자만 가능합니다.')

            return False

    # 예금 입금 이력 확인 메서드
    def deposit_history(self):
        print(f'***{self.name}님의 예금 입금 이력 리스트를 출력합니다.***')
        # 반복문으로 리스트를 순차적으로 출력
        for i in self.dps_list:
            print(i)

    # 예금 출금 이력 확인 메서드
    def withdraw_history(self):
        print(f'***{self.name}님의 예금 출금 이력 리스트를 출력합니다.***')
        # 반복문으로 리스트를 순차적으로 출력
        for i in self.wd_list:
            print(i)

# %% [markdown]
# ---
# # 최종 결과물

# %%
from random import *
import datetime

class Account:
    # 생성된 계좌 개수
    acc_cnt = 0

    # 은행이름 SC은행으로 고정
    bank = 'SC은행'
    # 예금주, 초기 잔액 입력
    def __init__(self, name, bal):
        # 예금주 속성
        self.name = name
        # 잔액 속성
        self.bal = bal

        # 계좌번호 랜덤 개설
        self.acc_num = ''

        rd = [str(randint(0, 10)) for i in range(11)]
        rd.insert(3, '-')
        rd.insert(6, '-')

        for i in rd:
            self.acc_num += i

        self.dps_cnt = 0

        # 입금 내역 리스트
        self.dps_list = []
        # 출금 내역 리스트
        self.wd_list = []

        #객체 생성 시, 계좌 개수 +1
        Account.acc_cnt += 1

    # 생성된 계좌 개수 출력 메서드
    def get_account_num(self):
        return print(f'생성된 계좌의 개수는 {Account.acc_cnt}개 입니다.')

    # 입금 메서드 정의
    def deposit(self):
        # 입금 시간 구하기
        d = datetime.datetime.now()

        self.dps_money = 0

        try:
            while self.dps_money == 0:
                self.dps_money = int(input('입금할 금액을 입력하세요: '))

                if self.dps_money == 0:
                    print('계좌 입금은 1원 이상부터 가능합니다.')
                else:
                    self.bal += self.dps_money
                    self.dps_list.append(f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.dps_money, ",")}원 예금 입금')
                    # 입금 횟수 카운트
                    self.dps_cnt += 1

            # 입금 횟수가 5의 배수가 되면 이자 추가
            if self.dps_cnt % 5 == 0:
                # 이자 = 원금의 1%
                interest = self.bal * 0.01
                self.bal += interest
                self.dps_list.append(
                    f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.dps_money, ",")}원 이자 입금')

            print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

            return True
        except:
            print('입금 금액 입력은 숫자만 가능합니다.')

            return False


    # 출금 메서드 정의
    def withdraw(self):
        # 출금 시간 구하기
        d = datetime.datetime.now()

        self.wd_money = self.bal + 1

        try:
            while self.wd_money > self.bal:
                self.wd_money = int(input('출금할 금액을 입력하세요: '))

                if self.wd_money > self.bal:
                    print(f'''계좌 출금은 잔액을 상회할 수 없습니다.
현재 {self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')
                else:
                    self.bal -= self.wd_money
                    self.wd_list.append(
                        f'{d.year}-{d.month}-{d.day} {d.hour}:{d.minute}:{d.second}, {format(self.wd_money, ",")}원 예금 출금')

            print(f'''처리가 완료되었습니다.
{self.name}님의 잔고는 {format(self.bal, ',')}원 입니다.''')

            return True
        except:
            print('입금 금액 입력은 숫자만 가능합니다.')

            return False


    # 계좌 정보 확인 메서드 정의
    def display_info(self):
        return print(f"개설된 계좌 정보 : (은행이름: {Account.bank}, 예금주: {self.name}), 계좌번호: {self.acc_num}, 잔고: {format(self.bal, ',')}")

    # 예금 입금 이력 확인 메서드
    def deposit_history(self):
        print(f'***{self.name}님의 예금 입금 이력 리스트를 출력합니다.***')
        for i in self.dps_list:
            print(i)

    # 예금 출금 이력 확인 메서드
    def withdraw_history(self):
        print(f'***{self.name}님의 예금 출금 이력 리스트를 출력합니다.***')
        for i in self.wd_list:
            print(i)


client_a = Account('이선재', 0)
client_b = Account('이창재', 10000000)
client_c = Account('이봉재', 20000)
client_d = Account('이현재', 5000)

# 고객 리스트 생성
client = [client_a, client_b, client_c, client_d]

# SC은행에 개설된 총 계좌 개수 확인
client_a.get_account_num()

# 계좌 입금
def deposit(client):
    dps_success = False
    while dps_success == False:
        if client.deposit():
            dps_success = True

            break



# 계좌 출금
def withdraw(client):
    wd_success = False
    while wd_success == False:
        if client.withdraw():
            wd_success = True

            break


# 잔고 100만워 이상 고객 탐색
def vip(client):
    print('계좌 잔고가 100만원 이상인 고객 정보를 탐색합니다.')
    print('*'*70)
    for i in client:
        if i.bal > 1000000:
            # 계좌 정보 확인
            i.display_info()

    print('*' * 70)


# 이자 계산을 위한 입금 6회
for i in range(6):
    deposit(client[0])
print()

# 예금 출금 함수 호출
withdraw(client[0])
print()

# 예금 입금 리스트 출력
for i in client:
    i.deposit_history()
    print()
print()

# 예금 출금 리스트 출력
for i in client:
    i.withdraw_history()
    print()
print()

# VIP 고객 정보 출력 함수 호출
vip(client)
# Out:
# 생성된 계좌의 개수는 4개 입니다.
# 입금할 금액을 입력하세요: 1000000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 1,000,000원 입니다.
# 입금할 금액을 입력하세요: 1000000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 2,000,000원 입니다.
# 입금할 금액을 입력하세요: 1000000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 3,000,000원 입니다.
# 입금할 금액을 입력하세요: 1000000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 4,000,000원 입니다.
# 입금할 금액을 입력하세요: 1000000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 5,050,000.0원 입니다.
# 입금할 금액을 입력하세요: 50000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 5,100,000.0원 입니다.
#
# 출금할 금액을 입력하세요: 100000
# 처리가 완료되었습니다.
# 이선재님의 잔고는 5,000,000.0원 입니다.
#
# ***이선재님의 예금 입금 이력 리스트를 출력합니다.***
# 2023-11-17 4:48:2, 1,000,000원 예금 입금
# 2023-11-17 4:48:8, 1,000,000원 예금 입금
# 2023-11-17 4:48:11, 1,000,000원 예금 입금
# 2023-11-17 4:48:14, 1,000,000원 예금 입금
# 2023-11-17 4:48:16, 1,000,000원 예금 입금
# 2023-11-17 4:48:16, 1,000,000원 이자 입금
# 2023-11-17 4:48:23, 50,000원 예금 입금
#
# ***이창재님의 예금 입금 이력 리스트를 출력합니다.***
#
# ***이봉재님의 예금 입금 이력 리스트를 출력합니다.***
#
# ***이현재님의 예금 입금 이력 리스트를 출력합니다.***
#
#
# ***이선재님의 예금 출금 이력 리스트를 출력합니다.***
# 2023-11-17 4:48:27, 100,000원 예금 출금
#
# ***이창재님의 예금 출금 이력 리스트를 출력합니다.***
#
# ***이봉재님의 예금 출금 이력 리스트를 출력합니다.***
#
# ***이현재님의 예금 출금 이력 리스트를 출력합니다.***
#
#
# 계좌 잔고가 100만원 이상인 고객 정보를 탐색합니다.
# **********************************************************************
# 개설된 계좌 정보 : (은행이름: SC은행, 예금주: 이선재), 계좌번호: 994-68-327069, 잔고: 5,000,000.0
# 개설된 계좌 정보 : (은행이름: SC은행, 예금주: 이창재), 계좌번호: 594-34-1035341, 잔고: 10,000,000
# **********************************************************************
