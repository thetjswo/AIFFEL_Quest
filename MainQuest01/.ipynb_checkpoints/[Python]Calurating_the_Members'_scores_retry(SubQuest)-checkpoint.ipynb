# %% [markdown]
# <a href="https://colab.research.google.com/github/thetjswo/Aiffel_Quest/blob/master/MainQuest01/MainQuest_Q2_fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Quest
# ---
# </br>
#
# ## 전체 문제
#
#
# 1.   코어 명단(딕셔너리)를 입력받아 학번을 부여하는 초기화 메서드를 작성해 보세요.
# >    * 코어 명단 : {강영현: 0, 김경민:0, 김민기: 0, 김승순: 0, 김양희: 0, 김영신:0, 오우진: 0, 윤혜윤: 0, 이상원: 0, 이선재: 0, 이슬: 0, 이승환: 0, 전민규: 0, 조보겸: 0, 조수민: 0, 최강훈: 0, 한현종: 0,홍채림: 0}
# 2.   Aiffel 클래스로부터 생성된 학번의 개수를 출력하는 get_id_num() 메서드를 추가하세요.
# 3.   Aiffel 클래스에 퀘스트 점수 입력을 위한 score 메서드를 추가하세요. 점수는 +1점 부터 +3점까지만 가능합니다.
# 4.   Aiffel 클래스에 퀘스트 점수 차감을 위한 penalty 메서드를 추가하세요. penalty로 인한 잔여 점수는 음수가 가능합니다.
# 5.   Aiffel 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 해당 메서드를 호출하면 이름, 학번, 과정종류, 퀘스트 점수 총점, 퀘스트 입력 총점, 퀘스트 penalty 총합이 새로운 코어명단(csv파일)로 출력되어야합니다.
# 6.   중도포기자 관리를 위해 그루정보를 삭제하는 메서드를 추가해보세요. 해당 메서드를 호출하면 명단이 갱신되어야 합니다. 현재 명단에서 김경민, 김영신 님을 삭제한 후 갱신된 명단을 출력하세요.
# 7.   Aiffel 클래스를 상속하여, 그루 명단을 바탕으로 2인, 3인, 4인으로 랜덤 그룹핑을 해주는 메서드가 추가된 Aiffel_Group 클래스를 만들어 보세요. 그룹이름은 총 8개입니다. (상생, 신뢰, 열정, 이끔, 성장, 가치, 공유, 확산)
# 8.   Aiffel 클래스를 상속하여, 그루 명단을 바탕으로 "힌튼", "응", "하사비스" 세개의 길드로 그루들을 랜덤 그룹핑 해주는 Aiffel_Guild 클래스를 만들어 보세요.
# 9.   Aiffel_Guild 클래스에 길드별 점수를 입력하고 차감하는 guild_score 메서드를 추가해보세요. guild_score 메서드는 길드 이름과 점수를 인자로 받고 길드별 스코어를 출력합니다. guild_score 메서드로 점수가 입력되거나 차감되면, Aiffel 클래스에서 구현된 개별 그루의 score도 소속 길드에서 추가되거나 차감된 점수에 따라 별도로 증감되어야 합니다.
# >    * ex) 모든 길드의 점수가 현재 0점이고, 김양희, 조수민, 조보겸 그루의 개별 점수가 각각 2,3,1이며, 박영수, 심지안 그루는 힌튼 길드, 박근수 그루는 응 길드 라고 했을 때, 힌튼 길드가 -1점, 응길드가 +1점을 받았다면 길드점수는 힌튼 길드 -1, 응 길드 +1, 하사비스 길드 +0이 되어야 하고 김양희, 조보겸 그루는 각각 1점과 0점, 조수민 그루는 4점이 되어야 합니다.
# 10.   Aiffel_Group 클래스에 group2guild_score 메서드를 추가하세요. group2guild_score 메서드는 아래와 같이 작동해야 합니다.
# >    * 랜덤으로 그룹핑된 그루들이 소속된 그룹의 이름으로 점수를 받게 되면, 각자 소속된 길드의 점수로 연동되어 계산되게 합니다.
# >    * ex) 이선재(Q8에서 응 길드원으로 랜덤 배치되었다 가정), 강영현(Q8에서 힌튼 길드원으로 랜덤 배치되었다 가정), 한현종(Q8에서 하사비스 길드원으로 랜덤 배치되었다 가정) 3명이 "상상" 그룹으로 그룹핑 되었을 때,상생 그룹이 +2점을 받으면 "응"길드와 "힌튼길드"와 "하사비스" 길드의 스코어는 각각 +2점이 되어야 합니다.
# 11.   Aiffel_Group 클래스와 Aiffel_Guild클래스가 Aiffel 클래스의 display_info() 메서드를 아래와 같이 오버라이딩 하도록 합니다.
# >    * 기존 명단에 길드별 스코어 총합이 보이도록 명단을 출력하도록 display_info()를 오버라이딩 합니다.
# <br/>
#
# </br>
#
# ## 목차
# 1. 코어 명단을 입력 받아 학번을 생성하는 생성자 정의
# 2. Aiffel 클래스 변수를 이용하여 학번 개수 출력
# 3. 각 그루원(Aiffel 객체)에게 퀘스트 점수를 부여하는 메서드 정의
# 4. 각 그루원(Aiffel 객체)에게 패널티 점수를 부여하는 메서드 정의
# 5. Aiffel 인스턴스의 정보를 출력하는 메서드 정의
# 6. 1번에서 입력받은 명단에서 특정 크루 삭제 메서드 정의
# 7. 랜덤으로 조를 추첨하는 클래스 정의
# 8. 랜덤으로 길드를 추첨하는 클래스 정의
# 9. 길드 점수와 그루 점수를 계산하는 메서드 정의
# 10. 조 점수를 길드 점수에 연동하는 메서드 정의
# 11. display_info() 메서드를 오버라이딩하여 길드 점수를 추가한 csv 출력 메서드 정의

# %% [markdown]
# ---
# # Q1. 코어 명단(딕셔너리)를 입력받아 학번을 부여하는 초기화 메서드를 작성해 보세요.
# <br/>
#
# ## 코어 명단을 입력 받아 학번을 생성하는 생성자 정의
#
#
# *   Aiffel 클래스 정의
# *   __init__() 생성자 정의
#     *   이름, 입학연도, 기수, 과정 등 필요한 속성 선언 및 초기화
#     *   코어 과정 모든 그루의 이름을 입력받아 리스트에 추가한다.
#     *   가나다 순의 순번을 포함한 딕셔너리를 클래스 변수에 할당
#     *   객체 생성을 할 때마다 입력을 받으면 비효율적이므로 입력 중단 플래그 설정
#     *   매개변수로 받은 기수를 코드로 치환
#     *   매개변수로 받은 과정을 코드로 치환
#     *   '연도의 뒷자리 + 기수 코드 + 과정 코드 + 가나다순 순번'으로 학번 생성
#     *   학번 개수 클래스 변수 +1 처리
# *   반복문을 사용하여 그루 객체 리스트 생성
#
# <br/>
#
# > ### 고려했던 사항
# > * 그루 이름 + enter로 그루 이름을 전부 입력하는 방법이 거추장스러워 한 번의 입력으로 모든 객체를 핸들링해야 한다.
# >     * comprehension과 split() 개념을 사용했다.
# > * 정해진 코드의 조합으로 학번이 생성되어야 한다.
# >     * 치환된 모든 값을 str처리하여 병합했다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 코어과정 그루들의 이름을 입력하시오. : 강영현,김경민,김민기,김승순,김양희,김영신,오우진,윤혜윤,이상원,이선재,이슬,이승환,전민규,조보겸,조수민,최강훈,한현종,홍채림
# 강영현님의 학번은 2329201입니다.
# 김경민님의 학번은 2329202입니다.
# 김민기님의 학번은 2329203입니다.
# 김승순님의 학번은 2329204입니다.
# 김양희님의 학번은 2329205입니다.
# 김영신님의 학번은 2329206입니다.
# 오우진님의 학번은 2329207입니다.
# 윤혜윤님의 학번은 2329208입니다.
# 이상원님의 학번은 2329209입니다.
# 이선재님의 학번은 2329210입니다.
# 이슬님의 학번은 2329211입니다.
# 이승환님의 학번은 2329212입니다.
# 전민규님의 학번은 2329213입니다.
# 조보겸님의 학번은 2329214입니다.
# 조수민님의 학번은 2329215입니다.
# 최강훈님의 학번은 2329216입니다.
# 한현종님의 학번은 2329217입니다.
# 홍채림님의 학번은 2329218입니다.
# ```

# %%
class Aiffel:
    # 코어 과정 그루들의 순번 딕셔너리 입력 여부 플래그
    list_status = 0
    # 코어 과정 그루들의 순번 딕셔너리
    core_mem = {}
    # 학생 수(객체 수) 체크
    std_num_cnt = 0

    def __init__(self, nm, ent, th, crs):
        # 이름 속성
        self.nm = nm
        # 입학연도 속성
        self.ent = ent
        # 기수 속성
        self.th = th
        # 과정 속성
        self.crs = crs
        # 퀘스트 점수 총점
        self.psn_score = 0
        # 퀘스트 입력 총점
        self.psn_score_sum = 0
        # 퀘스트 페널티 총점
        self.psn_penalty_sum = 0


        # 코어 명단 최초 1회만 입력
        if Aiffel.list_status == 0:
            # 코어과정 그루명 입력
            member = input('코어과정 그루들의 이름을 입력하시오. : ')
            # 입력받은 그루명을 ,를 구분자로 분리하여 리스트에 담기
            grew_list = member.split(',')

            # 입력된 이름 순으로 01~18까지 번호를 부여하여 딕셔너리에 저장
            for i in range(len(grew_list)):
                #번호가 10보다 작을 경우 순번을 01~09로 저장
                if i + 1 < 10:
                    v = '0' + str(i + 1)
                else:
                    v = str(i + 1)

                # 코어 멤버 딕셔너리에 담기
                Aiffel.core_mem[grew_list[i]] = v
            # 최초 1회 입력을 클래스 변수에 저장한 후, 플래그 변경으로 그 다음 객체 생성부터는 입력받지 않음
            Aiffel.list_status = 1

        # 기수 코드 치환
        if self.th == '온라인 7기':
            nn = '29'
        elif self.th == '온라인 6기':
            nn = '28'
        else:
            nn = '27'

        # 과정 코드 치환
        if self.crs == '코어':
            c = '2'
        else:
            c = '1'

        # 코어 과정 그루 딕셔너리에서  key값으로 이름을 비교하여 해당 이름에 할당된 순번 확인
        for k, v in Aiffel.core_mem.items():
            if self.nm == k:
                xx = v

        # 학번 생성
        self.std_num = self.ent[2:] + nn + c + xx
        print(f'{self.nm}님의 학번은 {self.std_num}입니다.')

        Aiffel.std_num_cnt += 1

# %% [markdown]
# ---
# # Q2. Aiffel 클래스로부터 생성된 학번의 개수를 출력하는 get_id_num() 메서드를 추가하세요.
#
# <br/>
#
# ## Aiffel 클래스 변수를 이용하여 학번 개수 출력
#
#
# *   get_id_num() 메서드 정의
#
# <br/>
#
# > ### 고려했던 사항
# > * Aiffel 클래스의 클래스 변수에 접근해야 한다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 학번의 개수는 18개 입니다.
# ```

# %%
    def get_id_num(self):
        return print(f'학번의 개수는 {Aiffel.std_num_cnt}개 입니다.')

# %% [markdown]
# ---
# # Q3. Aiffel 클래스에 퀘스트 점수 입력을 위한 score 메서드를 추가하세요. 점수는 +1점 부터 +3점까지만 가능합니다.
#
# <br/>
#
# ## 각 그루원(Aiffel 객체)에게 퀘스트 점수를 부여하는 메서드 정의
# *   score() 메서드 정의
#     *   입력한 점수가 1~3 범위 바깥일 경우에 대한 예외처리
#     *   개인 퀘스트 총점 갱신
#     *   입력 퀘스트 총점 갱신
#
# <br/>
#
# > ### 고려했던 사항
# > * 입력된 점수가 1~3 범위 안의 정수일 떄까지 입력을 반복해야 한다.
# > * 입력된 점수가 문자형일 경우 입력을 반복해야 한다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 이선재님에게 부여할 퀘스트 점수를 입력하세요(1~3): 5
# 점수는 1~3점으로 입력하세요.
# 이선재님에게 부여할 퀘스트 점수를 입력하세요(1~3): 하
# 점수는 1~3까지의 정수로 입력하세요.
# 이선재님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# ```

# %%
    def score(self):
        try:
            # 재입력 상황 대비 스코어를 0으로 초기화
            quest_score = 0

            # 입력한 점수가 1~3의 범위에 들 때까지 반복
            while quest_score < 1 or quest_score > 3:
                quest_score = int(input(f'{self.nm}님에게 부여할 퀘스트 점수를 입력하세요(1~3): '))

                # 점수가 1~3 사이인지 검증
                if 1 <= quest_score <= 3:
                    # 개인 퀘스트 총점
                    self.psn_score += quest_score
                    # 입력된 퀘스트 점수 총점
                    self.psn_score_sum += quest_score

                    return True
                else:
                    # 범위 내의 점수 입력 유도
                    print('점수는 1~3점으로 입력하세요.')

        except:
            # 문자 입력 시, 정수형 점수 입력 유도
            print('점수는 1~3까지의 정수로 입력하세요.')

            return False

for i in grew:
    score_status = False
    # return 값이 True일 때까지 반복
    while score_status == False:
        # 점수 정상 입력 시 종료
        if i.score() == True:
            break

# %% [markdown]
# ---
# # Q4. Aiffel 클래스에 퀘스트 점수 차감을 위한 penalty 메서드를 추가하세요. penalty로 인한 잔여 점수는 음수가 가능합니다.
#
# <br/>
#
# ## 각 그루원(Aiffel 객체)에게 패널티 점수를 부여하는 메서드 정의
# *   penalty() 메서드 정의
#     *   입력한 점수가 문자일 경우에 대한 예외처리
#     *   개인 퀘스트 총점 갱신
#     *   입력 패널티 총점 갱신
#
# <br/>
#
# > ### 고려했던 사항
# > * 입력된 점수가 문자형일 경우 입력을 반복해야 한다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 이선재 그루에게 부여할 패널티 점수를 입력하세요: 하
# 점수는 정수로만 입력하세요.
# 이선재 그루에게 부여할 패널티 점수를 입력하세요: 1
# ```

# %%
    def penality(self):
        # 퀘스트 점수는 음수가 될 수 있다.
        try:
            penalty_score = int(input(f'{self.nm} 그루에게 부여할 패널티 점수를 입력하세요: '))
            # 점수 총점 업데이트
            self.psn_score -= penalty_score
            # 패널티 점수 총점 업데이트
            self.psn_penalty_sum += penalty_score

            return True
        except:
            # 문자 입력 시, 정수형 점수 입력 유도
            print('점수는 정수로만 입력하세요.')

            return False


for i in grew:
    penalty_status = False
    # return 값이 True일 때까지 반복
    while penalty_status == False:
        # 점수 정상 입력 시 종료
        if i.penality() == True:
            break

# %% [markdown]
# ---
# # Q5. Aiffel 인스턴스에 저장된 정보를 출력하는 display_info() 메서드를 추가하세요. 해당 메서드를 호출하면 이름, 학번, 과정종류, 퀘스트 점수 총점, 퀘스트 입력 총점, 퀘스트 penalty 총합이 새로운 코어명단(csv파일)로 출력되어야합니다.
#
# <br/>
#
# ## Aiffel 인스턴스의 정보를 출력하는 메서드 정의
# *   display_info() 메서드 정의
#     *   그루 객체의 정보를 담고 있는 리스트 생성
# *  return된 리스트를 순차적으로 입력하여 csv 파일 생성
#     * field를 생성하고 리스트를 순차적으로 row에 추가
#
# <br/>
#
# > ### 고려했던 사항
# > * csv 파일 생성 로직을 display_info()메서드에 넣고 싶은데 객체 정보를 순차적으로 추가하는 부분에서 막혔다.
#
# </br>
#
#
# # 처리결과
#
# ![스크린샷 2023-11-20 오전 12.49.01.png](data:image/png;base64,...)

# %%
    def display_info(self):
        # csv 파일에 입력할 데이터 리스트 생성
        list = [self.nm, self.std_num, self.crs, self.psn_score, self.psn_score_sum,self.psn_penalty_sum]


        return list


# csv 파일 출력
# 필드 리스트 생성
field_list = ['이름','학번','과정','퀘스트 총점','퀘스트 입력 총점','퀘스트 패널티 총점']
# 빈 로우 리스트 생성
row_list = []

# 각 객체 정보 리스트에 추가
for i in grew:
    row_list.append(i.display_info())
with open(f'/Users/leeseonjae/Downloads/grew_data.csv','w',newline='') as f:
    writer = csv.writer(f)
    # 1행에 필드 추가
    writer.writerow(field_list)
    # 2행부터 로우 추가
    writer.writerows(row_list)

# %% [markdown]
# ---
# # Q6. 중도포기자 관리를 위해 그루정보를 삭제하는 메서드를 추가해보세요. 해당 메서드를 호출하면 명단이 갱신되어야 합니다. 현재 명단에서 김경민, 김영신 님을 삭제한 후 갱신된 명단을 출력하세요.
#
# <br/>
#
# ## 1번에서 입력받은 명단에서 특정 크루 삭제 메서드 정의
# *   delete_grew() 메서드 정의
#     *   매개변수로 받은 이름의 그루 정보를 딕셔너리에서 삭제
#     *   갱신된 그루 명단 출력
#
# <br/>
#
# > ### 고려했던 사항
# > * 그루 정보가 삭제되면 가나다순 순번은 앞으로 당겨져야 하는가?
#     * 순번이 당겨지게 되면 학번이 변경되므로 순번은 그대로 유지
#
# </br>
#
#
# # 처리결과
#
# ```
# 코어 과정 그루 목록에서 김경민님을 삭제합니다.
# 갱신된 그루 목록은 {'강영현': '01', '김민기': '03', '김승순': '04', '김양희': '05', '김영신': '06', '오우진': '07', '윤혜윤': '08', '이상원': '09', '이선재': '10', '이슬': '11', '이승환': '12', '전민규': '13', '조보겸': '14', '조수민': '15', '최강훈': '16', '한현종': '17', '홍채림': '18'}입니다.
# 코어 과정 그루 목록에서 김영신님을 삭제합니다.
# 갱신된 그루 목록은 {'강영현': '01', '김민기': '03', '김승순': '04', '김양희': '05', '오우진': '07', '윤혜윤': '08', '이상원': '09', '이선재': '10', '이슬': '11', '이승환': '12', '전민규': '13', '조보겸': '14', '조수민': '15', '최강훈': '16', '한현종': '17', '홍채림': '18'}입니다.
# ```

# %%
    def delete_grew(self, name):
        # name 키와 그 키의 밸류 삭제
        print(f'코어 과정 그루 목록에서 {name}님을 삭제합니다.')
        del Aiffel.core_mem[name]

        #삭제된 인원 뒤에 있는 그루들의 순번이 바뀌게 되면 학번도 바뀌어야 하므로 순번은 유지
        return print(f'갱신된 그루 목록은 {Aiffel.core_mem}입니다.')


grew[0].delete_grew('김경민')
grew[0].delete_grew('김영신')

# %% [markdown]
# ---
# # Q7. Aiffel 클래스를 상속하여, 그루 명단을 바탕으로 2인, 3인, 4인으로 랜덤 그룹핑을 해주는 메서드가 추가된 Aiffel_Group 클래스를 만들어 보세요. 그룹이름은 총 8개입니다. (상생, 신뢰, 열정, 이끔, 성장, 가치, 공유, 확산)
#
# <br/>
#
# ## 랜덤으로 조를 추첨하는 클래스 정의
# *   Aiffel 클래스로부터 상속받는 AiffelGroup 클래스 정의
# *   __init__() 생성자 정의
#     *   Aiffel 클래스로부터 그루 명단 딕셔너리를 상속받아 그루 이름 리스트 생성
#     *   random 모듈을 이용하여 2~4명 중 랜덤한 숫자로 구성된 그루들을 셔플
#     *   생성한 조원들을 조 딕셔너리에 추가
#
# <br/>
#
# > ### 고려했던 사항
# > * 조가 결정된 그루들의 이름은 그루 명단 리스트에서 제거가 되어야 중복을 방지할 수 있다.
# > * 셔플을 통해 추출할 무작위 값의 범위는 전체 리스트의 크기보다 크면 안된다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 추첨된 조는 {'상생': ['이승환', '김민기', '이상원'], '신뢰': ['강영현', '이선재'], '열정': ['윤혜윤', '조수민', '홍채림', '한현종'], '이끔': ['전민규', '이슬'], '성장': ['조보겸', '최강훈', '김승순', '김양희'], '가치': [], '공유': [], '확산': []} 입니다.
# ```

# %%
class AiffelGroup(Aiffel):
    def __init__(self):
        # 그루 이름으로 구성된 리스트 생성
        self.grew_mem = [i for i in Aiffel.core_mem]
        self.group_nm = {'상생': '', '신뢰': '', '열정': '', '이끔': '', '성장': '', '가치': '', '공유': '', '확산': ''}

        for k,v in self.group_nm.items():
            # 인덱스 별 value에 2~4명의 랜덤 그루 배정
            if len(self.grew_mem) >= 4:
                self.group_nm[k] = random.sample(self.grew_mem, random.randint(2, 4))
                # 배정된 그루는 리스트에서 제거
                for x in self.group_nm[k]:
                    self.grew_mem.remove(x)
            else:
                # 나머지 연산
                self.group_nm[k] = self.grew_mem
                # 배정된 그루는 리스트에서 제거
                for x in self.group_nm[k]:
                    self.grew_mem.remove(x)
        return print(f'추첨된 조는 {self.group_nm} 입니다.')


aiffel_group = AiffelGroup()

# %% [markdown]
# ---
# # Q8. Aiffel 클래스를 상속하여, 그루 명단을 바탕으로 "힌튼", "응", "하사비스" 세개의 길드로 그루들을 랜덤 그룹핑 해주는 Aiffel_Guild 클래스를 만들어 보세요.
#
# <br/>
#
# ## 랜덤으로 길드를 추첨하는 클래스 정의
# *   Aiffel 클래스로부터 상속받는 AiffelGuild 클래스 정의
# *   __init__() 생성자 정의
#     *   Aiffel 클래스로부터 그루 명단 딕셔너리를 상속받아 그루 이름 리스트 생성
#     *   random 모듈을 이용하여 5~6명 중 랜덤한 숫자로 구성된 그루들을 셔플
#     *   생성한 길드원들을 길드 딕셔너리에 추가
#
# <br/>
#
# > ### 고려했던 사항
# > * 길드가 결정된 그루들의 이름은 그루 명단 리스트에서 제거가 되어야 중복을 방지할 수 있다.
# > * 셔플을 통해 추출할 무작위 값의 범위는 전체 리스트의 크기보다 크면 안된다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 추첨된 길드는 {'힌튼': ['조수민', '윤혜윤', '조보겸', '전민규', '이선재', '최강훈'], '응': ['김양희', '이상원', '홍채림', '김민기', '오우진', '한현종'], '하사비스': ['강영현', '김승순', '이슬', '이승환']}입니다.
# ```

# %%
class AiffelGuild(Aiffel):
    def __init__(self):
        # 길드 스코어 속성
        self.guild_scr = {'응':0,'힌튼':0, '하사비스':0}
        # 그루 이름으로 구성된 리스트 생성
        self.grew_mem = [i for i in Aiffel.core_mem]
        # 그루가 배정돤 길드 딕셔너리 초기화
        self.guild_nm = {'힌튼': '', '응': '', '하사비스': ''}

        # 인덱스 별 value에 5~6명의 랜덤 그루 배정
        for k,v in self.guild_nm.items():
            # list의 그루 수가 6명보다 클 때 5 혹은 6의 랜덤 값으로 길드 배정
            if len(self.grew_mem) >= 6:
                # 그루 리스트에서 무작위 인원을 5 혹은 6명으로 랜덤 배정
                self.guild_nm[k] = random.sample(self.grew_mem, random.randint(5, 6))
                # 배정된 그루는 리스트에서 제거
                for x in self.guild_nm[k]:
                    self.grew_mem.remove(x)
            # list의 그루 수가 6명보다 작으면 남아 있는 인원들을 남은 길드에 배정
            else:
                self.guild_nm[k] = self.grew_mem
        return print(f'추첨된 길드는 {self.guild_nm}입니다.')


aiffel_guild = AiffelGuild()

# %% [markdown]
# ---
# # Q9. Aiffel_Guild 클래스에 길드별 점수를 입력하고 차감하는 guild_score 메서드를 추가해보세요. guild_score 메서드는 길드 이름과 점수를 인자로 받고 길드별 스코어를 출력합니다. guild_score 메서드로 점수가 입력되거나 차감되면, Aiffel 클래스에서 구현된 개별 그루의 score도 소속 길드에서 추가되거나 차감된 점수에 따라 별도로 증감되어야 합니다.
#
# <br/>
#
# ## 길드 점수와 그루 점수를 계산하는 메서드 정의
# *   guild_score() 메서드 정의
#       * 매개변수로 전달받은 점수를 길드 점수에 더한 후 출력
#       * AiffelGuild 클래스의 객체 속성과 Aiffel 클래스의 객체 속성을 비교하여 점수를 부여받은 길드의 그루에게 같은 점수 합산
#
# <br/>
#
# > ### 고려했던 사항
# > * 길드에 포함된 길드원의 정보를 갱신하기 위해서는 Aiffel 클래스의 객체 정보에 접근해야 한다.
# > * 중첩 반복문과 조건문이 많이 사용되어 어떤 데이터를 핸들링하는지 정확하게 파악해야 한다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 힌튼 길드의 이선재 그루는 -1점 획득했으므로, 현재 -1점입니다.
# ```

# %%
    def guild_score(self, name, score, grew):
        for i in self.guild_nm:
            # 입력 받은 길드 이름과 딕셔너리 인덱스의 키 값이 같을 때
            # True : 길드명 == 길드명
            if name == i:
                # 길드 점수 갱신
                self.guild_scr[name] += score
                print(f'{name}길드의 점수는 {self.guild_scr[name]}점입니다.')

                # 이중 for문으로 그루 이름 비교
                for x in self.guild_nm[i]:
                    for y in grew:
                        if x == y.nm:
                            # 매개변수로 넘어온 점수가 음수일 경우
                            if score < 0:
                                # 총점 갱신
                                y.psn_score += score
                                # 패널티 총점 갱신
                                y.psn_penalty_sum -= score
                            # 매개변수로 넘어온 점수가 양수일 경우
                            else:
                                # 총점 갱신
                                y.psn_score += score
                                # 합산 점수 갱신
                                y.psn_score_sum += score
                            print(f'{i} 길드의 {y.nm} 그루는 {score}점 획득했으므로, 현재 {y.psn_score}점입니다.')


aiffel_guild.guild_score('힌튼',-1,grew)

# %% [markdown]
# ---
# # Q10. Aiffel_Group 클래스에 group2guild_score 메서드를 추가하세요. group2guild_score 메서드는 아래와 같이 작동해야 합니다.
#
# <br/>
#
# ## 조 점수를 길드 점수에 연동하는 메서드 정의
# *   group2guild_score() 메서드 정의
#       * AiffelGuild 클래스의 객체 속성과 AiffelGroup 클래스의 객체 속성을 비교하여 점수를 부여받은 조의 그루가 속한 길드의 점수에 추가
#       * AiffelGuild 클래스 객체의 guild_score() 메서드 호출
#
# <br/>
#
# > ### 고려했던 사항
# > * guild_score() 메서드를 호출해야 하기 때문에 호출에 필요한 인수를 미리 매개변수로 전달 받아야 한다.
# > * 중첩 반복문과 조건문이 많이 사용되어 어떤 데이터를 핸들링하는지 정확하게 파악해야 한다.
# > * 좀 더 깔끔한 방법으로 데이터를 비교하고 싶었지만 마땅한 방법이 떠오르지 않는다.
#
# </br>
#
#
# # 처리결과
#
# ```
# 신뢰조가 1점을 획득하여 조원인 이선재님의 소속인 힌튼 길드에 1이 연동됩니다.
# 힌튼길드의 점수는 0점입니다.
# 힌튼 길드의 이선재 그루는 1점 획득했으므로, 현재 0점입니다.
# ```

# %%
    def group2guild_score(self, name, score, guild, grew):
        for i in self.group_nm:
            # 조 이름 검증
            # 조 == 조
            if name == i:
                # 길드 검증
                for x in self.group_nm[i]:
                    # x == 그루 이름
                    for y in guild.guild_nm:
                        # y == 길드명
                        for z in guild.guild_nm[y]:
                            if x == z:
                                # 길드 점수 갱신 메서드 호출
                                print()
                                print(f'{name}조가 {score}점을 획득하여 조원인 {x}님의 소속인 {y} 길드에 {score}이 연동됩니다.')
                                guild.guild_score(y,score,grew)


aiffel_group.group2guild_score('신뢰',1,aiffel_guild, grew)

# %% [markdown]
# ---
# # Q11. Aiffel_Group 클래스와 Aiffel_Guild클래스가 Aiffel 클래스의 display_info() 메서드를 아래와 같이 오버라이딩 하도록 합니다.
#
# <br/>
#
# ## display_info() 메서드를 오버라이딩하여 길드 점수를 추가한 csv 출력 메서드 정의
# *   Aiffel클래스의 display_info() 메서드를 오버라이딩하는 display_info() 메서드 정의
#       * Aiffel 클래스의 객체 리스트를 매개변수로 받아 각 그루의 소속 길드와 그 길드의 점수 데이터를 리스트에 추가
#       * 생성된 리스트를 로우 데이터에 순차적으로 추가하여 csv 생성
#
# <br/>
#
# > ### 고려했던 사항
# > * 오버라이딩의 개념을 파악해야 한다.
# > * 중첩 반복문과 조건문이 많이 사용되어 어떤 데이터를 핸들링하는지 정확하게 파악해야 한다.
# > * 기존 명단에서 그루들에게 맞는길드와 길드 점수 데이터가 삽입되어야 한다.
#
# </br>
#
#
# # 처리결과
#
# ![스크린샷 2023-11-20 오전 1.26.56.png](data:image/png;base64,...)

# %% [markdown]
# ---
# # 최종 결과물
#
# <br/>
#
# ## 정의부

# %%
# csv 모듈 import
import csv
import random
import pandas as pd
from IPython.display import display

#Aiffel 클래스 정의
class Aiffel:
    # 코어 과정 그루들의 순번 딕셔너리 입력 여부 플래그
    list_status = 0
    # 코어 과정 그루들의 순번 딕셔너리
    core_mem = {}
    # 학생 수(객체 수) 체크
    std_num_cnt = 0

    def __init__(self, nm, ent, th, crs):
        # 이름 속성
        self.nm = nm
        # 입학연도 속성
        self.ent = ent
        # 기수 속성
        self.th = th
        # 과정 속성
        self.crs = crs
        # 퀘스트 점수 총점
        self.psn_score = 0
        # 퀘스트 입력 총점
        self.psn_score_sum = 0
        # 퀘스트 페널티 총점
        self.psn_penalty_sum = 0


        # 코어 명단 최초 1회만 입력
        if Aiffel.list_status == 0:
            # 코어과정 그루명 입력
            member = input('코어과정 그루들의 이름을 입력하시오. : ')
            # 입력받은 그루명을 ,를 구분자로 분리하여 리스트에 담기
            grew_list = member.split(',')

            # 입력된 이름 순으로 01~18까지 번호를 부여하여 딕셔너리에 저장
            for i in range(len(grew_list)):
                #번호가 10보다 작을 경우 순번을 01~09로 저장
                if i + 1 < 10:
                    v = '0' + str(i + 1)
                else:
                    v = str(i + 1)

                # 코어 멤버 딕셔너리에 담기
                Aiffel.core_mem[grew_list[i]] = v
            # 최초 1회 입력을 클래스 변수에 저장한 후, 플래그 변경으로 그 다음 객체 생성부터는 입력받지 않음
            Aiffel.list_status = 1

        # 기수 코드 치환
        if self.th == '온라인 7기':
            nn = '29'
        elif self.th == '온라인 6기':
            nn = '28'
        else:
            nn = '27'

        # 과정 코드 치환
        if self.crs == '코어':
            c = '2'
        else:
            c = '1'

        # 코어 과정 그루 딕셔너리에서  key값으로 이름을 비교하여 해당 이름에 할당된 순번 확인
        for k, v in Aiffel.core_mem.items():
            if self.nm == k:
                xx = v

        # 학번 생성
        self.std_num = self.ent[2:] + nn + c + xx
        print(f'{self.nm}님의 학번은 {self.std_num}입니다.')

        Aiffel.std_num_cnt += 1

    # 학번 개수 출력 메서드 정의
    def get_id_num(self):
        return print(f'학번의 개수는 {Aiffel.std_num_cnt}개 입니다.')

    # 점수 입력 메서드 정의
    def score(self):
        try:
            # 재입력 상황 대비 스코어를 0으로 초기화
            quest_score = 0

            # 입력한 점수가 1~3의 범위에 들 때까지 반복
            while quest_score < 1 or quest_score > 3:
                quest_score = int(input(f'{self.nm}님에게 부여할 퀘스트 점수를 입력하세요(1~3): '))

                # 점수가 1~3 사이인지 검증
                if 1 <= quest_score <= 3:
                    # 개인 퀘스트 총점
                    self.psn_score += quest_score
                    # 입력된 퀘스트 점수 총점
                    self.psn_score_sum += quest_score

                    return True
                else:
                    # 범위 내의 점수 입력 유도
                    print('점수는 1~3점으로 입력하세요.')

        except:
            # 문자 입력 시, 정수형 점수 입력 유도
            print('점수는 1~3까지의 정수로 입력하세요.')

            return False

    # 패널티 메서드 정의
    def penality(self):
        # 퀘스트 점수는 음수가 될 수 있다.
        try:
            penalty_score = int(input(f'{self.nm} 그루에게 부여할 패널티 점수를 입력하세요: '))
            # 점수 총점 업데이트
            self.psn_score -= penalty_score
            # 패널티 점수 총점 업데이트
            self.psn_penalty_sum += penalty_score

            return True
        except:
            # 문자 입력 시, 정수형 점수 입력 유도
            print('점수는 정수로만 입력하세요.')

            return False

    # 객체 정보 호출 메서드 정의
    def display_info(self):
        # csv 파일에 입력할 데이터 리스트 생성
        list = [self.nm, self.std_num, self.crs, self.psn_score, self.psn_score_sum,self.psn_penalty_sum]

        # csv와 별개로 결과값 확인을 위한 dataframe 생성
        grew_data = {
            'Fields' : ['이름','학번','과정','퀘스트 총점','퀘스트 입력 총점','퀘스트 패널티 총점'],
            'Rows' : [getattr(self,'nm',None),
                      getattr(self,'std_num',None),
                      getattr(self,'crs',None),
                      getattr(self,'psn_score',None),
                      getattr(self,'psn_score_sum',None),
                      getattr(self,'psn_penalty_sum',None)]
        }

        grew_df = pd.DataFrame(grew_data)
        display(grew_df)

        return list

    # 중도 포기 그루 삭제 메서드 정의
    def delete_grew(self, name):
        # name 키와 그 키의 밸류 삭제
        print(f'코어 과정 그루 목록에서 {name}님을 삭제합니다.')
        del Aiffel.core_mem[name]

        #삭제된 인원 뒤에 있는 그루들의 순번이 바뀌게 되면 학번도 바뀌어야 하므로 순번은 유지
        return print(f'갱신된 그루 목록은 {Aiffel.core_mem}입니다.')


# Aiffel_Group 클래스 정의
class AiffelGroup(Aiffel):
    def __init__(self):
        # 그루 이름으로 구성된 리스트 생성
        self.grew_mem = [i for i in Aiffel.core_mem]
        self.group_nm = {'상생': '', '신뢰': '', '열정': '', '이끔': '', '성장': '', '가치': '', '공유': '', '확산': ''}

        for k,v in self.group_nm.items():
            # 인덱스 별 value에 2~4명의 랜덤 그루 배정
            if len(self.grew_mem) >= 4:
                self.group_nm[k] = random.sample(self.grew_mem, random.randint(2, 4))
                # 배정된 그루는 리스트에서 제거
                for x in self.group_nm[k]:
                    self.grew_mem.remove(x)
            else:
                # 나머지 연산
                self.group_nm[k] = self.grew_mem
                # 배정된 그루는 리스트에서 제거
                for x in self.group_nm[k]:
                    self.grew_mem.remove(x)
        return print(f'추첨된 조는 {self.group_nm} 입니다.')

    # 조별 점수 - 길드 점수 연동 메서드
    def group2guild_score(self, name, score, guild, grew):
        for i in self.group_nm:
            # 조 이름 검증
            # 조 == 조
            if name == i:
                # 길드 검증
                for x in self.group_nm[i]:
                    # x == 그루 이름
                    for y in guild.guild_nm:
                        # y == 길드명
                        for z in guild.guild_nm[y]:
                            if x == z:
                                # 길드 점수 갱신 메서드 호출
                                print()
                                print(f'{name}조가 {score}점을 획득하여 조원인 {x}님의 소속인 {y} 길드에 {score}이 연동됩니다.')
                                guild.guild_score(y,score,grew)



# Aiffel_Guild 클래스 정의
class AiffelGuild(Aiffel):
    def __init__(self):
        # 길드 스코어 속성
        self.guild_scr = {'응':0,'힌튼':0, '하사비스':0}
        # 그루 이름으로 구성된 리스트 생성
        self.grew_mem = [i for i in Aiffel.core_mem]
        # 그루가 배정돤 길드 딕셔너리 초기화
        self.guild_nm = {'힌튼': '', '응': '', '하사비스': ''}

        # 인덱스 별 value에 5~6명의 랜덤 그루 배정
        for k,v in self.guild_nm.items():
            # list의 그루 수가 6명보다 클 때 5 혹은 6의 랜덤 값으로 길드 배정
            if len(self.grew_mem) >= 6:
                # 그루 리스트에서 무작위 인원을 5 혹은 6명으로 랜덤 배정
                self.guild_nm[k] = random.sample(self.grew_mem, random.randint(5, 6))
                # 배정된 그루는 리스트에서 제거
                for x in self.guild_nm[k]:
                    self.grew_mem.remove(x)
            # list의 그루 수가 6명보다 작으면 남아 있는 인원들을 남은 길드에 배정
            else:
                self.guild_nm[k] = self.grew_mem
        return print(f'추첨된 길드는 {self.guild_nm}입니다.')

    # 길드 점수 입력 메서드
    def guild_score(self, name, score, grew):
        for i in self.guild_nm:
            # 입력 받은 길드 이름과 딕셔너리 인덱스의 키 값이 같을 때
            # True : 길드명 == 길드명
            if name == i:
                # 길드 점수 갱신
                self.guild_scr[name] += score
                print(f'{name}길드의 점수는 {self.guild_scr[name]}점입니다.')

                # 이중 for문으로 그루 이름 비교
                for x in self.guild_nm[i]:
                    for y in grew:
                        if x == y.nm:
                            # 매개변수로 넘어온 점수가 음수일 경우
                            if score < 0:
                                # 총점 갱신
                                y.psn_score += score
                                # 패널티 총점 갱신
                                y.psn_penalty_sum -= score
                            # 매개변수로 넘어온 점수가 양수일 경우
                            else:
                                # 총점 갱신
                                y.psn_score += score
                                # 합산 점수 갱신
                                y.psn_score_sum += score
                            print(f'{i} 길드의 {y.nm} 그루는 {score}점 획득했으므로, 현재 {y.psn_score}점입니다.')

    # 길드 점수 정보 표시를 위한 display_info 메서드 오버라이딩
    def display_info(self, grew):
        field_list = ['이름', '학번', '과정', '퀘스트 총점', '퀘스트 입력 총점', '퀘스트 패널티 총점', '소속 길드', '길드 점수']
        row_list = []
        # 길드 이름 딕셔너리 루프 : x = 길드명
        for x in self.guild_nm:
            # 길드에 소속된 그루 루프 : y = 길드원
            for y in self.guild_nm[x]:
                # grew 객체 루프 : z = 그루 객체
                for z in grew:
                    # 그루 이름 == 길드원 이름
                    if z.nm == y:
                        # 길드 점수 딕셔너리 루프 : i = 길드명
                        for i in self.guild_scr:
                            # guild.nm 길드명과 guild.scr 길드명이 같을 때
                            if x == i:
                                # csv 파일에 입력할 데이터 리스트 생성
                                row_list.append([z.nm, z.std_num, z.crs, z.psn_score, z.psn_score_sum, z.psn_penalty_sum, x, self.guild_scr[i]])

        with open(f'/content//grew_guild_data.csv', 'w', newline='') as f:
            writer = csv.writer(f)
            # 1행에 필드 추가
            writer.writerow(field_list)
            # 2행부터 로우 추가
            writer.writerows(row_list)

# %% [markdown]
# <br/>
#
# ## 호출부

# %%
# 그루 리스트 생성
grew_name_list = ['강영현','김경민','김민기','김승순','김양희','김영신','오우진','윤혜윤','이상원','이선재','이슬','이승환','전민규','조보겸','조수민','최강훈','한현종','홍채림']

# 그루 객체 리스트 생성
grew = [Aiffel(i,'2023','온라인 7기','코어') for i in grew_name_list]

# 학번 개수 확인
grew[0].get_id_num()
print('\n')

# 퀘스트 점수 입력 메서드 호출
print('*'*24,'퀘스트 점수 입력','*'*24)
for i in grew:
    score_status = False
    # return 값이 True일 때까지 반복
    while score_status == False:
        # 점수 정상 입력 시 종료
        if i.score() == True:
            break
print('*'*62)
print('\n')

# 페널티 점수 입력 메서드 호출
print('*'*24,'패널티 점수 입력','*'*24)
for i in grew:
    penalty_status = False
    # return 값이 True일 때까지 반복
    while penalty_status == False:
        # 점수 정상 입력 시 종료
        if i.penality() == True:
            break
print('*'*62)
print('\n')

print('*'*22,'개인 퀘스트 정보 출력','*'*22)
# csv 파일 출력
# 필드 리스트 생성
field_list = ['이름','학번','과정','퀘스트 총점','퀘스트 입력 총점','퀘스트 패널티 총점']
# 빈 로우 리스트 생성
row_list = []

# 각 객체 정보 리스트에 추가
for i in grew:
    row_list.append(i.display_info())
with open(f'/content/grew_data.csv','w',newline='') as f:
    writer = csv.writer(f)
    # 1행에 필드 추가
    writer.writerow(field_list)
    # 2행부터 로우 추가
    writer.writerows(row_list)
print('*'*62)
print('\n')

# 김경민, 김영신 그루 삭제
print('*'*21,'김경민, 김영신 그루 삭제','*'*21)
grew[0].delete_grew('김경민')
grew[0].delete_grew('김영신')
print('*'*62)
print('\n')

print('*'*22,'길드 및 조 랜덤 배정','*'*22)
aiffel_group = AiffelGroup()
aiffel_guild = AiffelGuild()
print('*'*62)
print('\n')

# 길드 점수 갱신 메서드 호출
print('*'*21,'길드 및 개인 점수 확인','*'*21)
aiffel_guild.guild_score('응',2,grew)
print()
aiffel_guild.guild_score('힌튼',-1,grew)
print()
aiffel_guild.guild_score('하사비스',1,grew)
print('*'*62)
print('\n')

# 그룹 점수 갱신 메서드 호출
print('*'*22,'조 점수를 길드에 연동','*'*22)
aiffel_group.group2guild_score('상생',3,aiffel_guild, grew)
print()
aiffel_group.group2guild_score('신뢰',1,aiffel_guild, grew)
print()
aiffel_group.group2guild_score('열정',2,aiffel_guild, grew)
print()
aiffel_group.group2guild_score('이끔',3,aiffel_guild, grew)
print()
aiffel_group.group2guild_score('성장',3,aiffel_guild, grew)
print('*'*66)
print('\n')

# 길드 점수를 포함한 display_info 메서드 오버라이딩
aiffel_guild.display_info(grew)
# Out:
# 코어과정 그루들의 이름을 입력하시오. : 강영현,김경민,김민기,김승순,김양희,김영신,오우진,윤혜윤,이상원,이선재,이슬,이승환,전민규,조보겸,조수민,최강훈,한현종,홍채림
# 강영현님의 학번은 2329201입니다.
# 김경민님의 학번은 2329202입니다.
# 김민기님의 학번은 2329203입니다.
# 김승순님의 학번은 2329204입니다.
# 김양희님의 학번은 2329205입니다.
# 김영신님의 학번은 2329206입니다.
# 오우진님의 학번은 2329207입니다.
# 윤혜윤님의 학번은 2329208입니다.
# 이상원님의 학번은 2329209입니다.
# 이선재님의 학번은 2329210입니다.
# 이슬님의 학번은 2329211입니다.
# 이승환님의 학번은 2329212입니다.
# 전민규님의 학번은 2329213입니다.
# 조보겸님의 학번은 2329214입니다.
# 조수민님의 학번은 2329215입니다.
# 최강훈님의 학번은 2329216입니다.
# 한현종님의 학번은 2329217입니다.
# 홍채림님의 학번은 2329218입니다.
# 학번의 개수는 18개 입니다.
#
#
# ************************ 퀘스트 점수 입력 ************************
# 강영현님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 김경민님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 김민기님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 김승순님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 김양희님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 김영신님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 오우진님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 윤혜윤님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 이상원님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 이선재님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# 이슬님에게 부여할 퀘스트 점수를 입력하세요(1~3): 1
# ...

# %% [markdown]
# ## grew_data.csv
# |이름|학번|과정|퀘스트 총점|퀘스트 입력 총점|퀘스트 패널티 총점|
# |---|---|---|---|---|---|
# |강영현|2329201|코어|0|1|1|
# |김경민|2329202|코어|0|1|1|
# |김민기|2329203|코어|0|1|1|
# |김승순|2329204|코어|0|1|1|
# |김양희|2329205|코어|0|1|1|
# |김영신|2329206|코어|0|1|1|
# |오우진|2329207|코어|0|1|1|
# |윤혜윤|2329208|코어|0|1|1|
# |이상원|2329209|코어|0|1|1|
# |이선재|2329210|코어|0|1|1|
# |이슬|2329211|코어|0|1|1|
# |이승환|2329212|코어|0|1|1|
# |전민규|2329213|코어|0|1|1|
# |조보겸|2329214|코어|0|1|1|
# |조수민|2329215|코어|0|1|1|
# |최강훈|2329216|코어|0|1|1|
# |한현종|2329217|코어|0|1|1|
# |홍채림|2329218|코어|0|1|1|
#
# <br/>
#
# <br/>
#
# ## grew_guild_data.csv
# |이름|학번|과정|퀘스트 총점|퀘스트 입력 총점|퀘스트 패널티 총점|소속 길드|길드 점수|
# |---|---|---|---|---|---|---|---|
# |이승환|2329212|코어|11|13|2|힌튼|11|
# |한현종|2329217|코어|11|13|2|힌튼|11|
# |강영현|2329201|코어|11|13|2|힌튼|11|
# |전민규|2329213|코어|11|13|2|힌튼|11|
# |오우진|2329207|코어|11|13|2|힌튼|11|
# |조보겸|2329214|코어|11|13|2|힌튼|11|
# |이슬|2329211|코어|10|11|1|응|10|
# |김민기|2329203|코어|10|11|1|응|10|
# |김승순|2329204|코어|10|11|1|응|10|
# |홍채림|2329218|코어|10|11|1|응|10|
# |김양희|2329205|코어|10|11|1|응|10|
# |윤혜윤|2329208|코어|12|13|1|하사비스|12|
# |이상원|2329209|코어|12|13|1|하사비스|12|
# |이선재|2329210|코어|12|13|1|하사비스|12|
# |조수민|2329215|코어|12|13|1|하사비스|12|
# |최강훈|2329216|코어|12|13|1|하사비스|12|

# %% [markdown]
# ---
# # 회고
# KEEP
#  - 마무리 짓지 못한 문제를 포기하지 않고 풀었다.
#  - 클래스의 상속 관계를 이해하며 문제를 해결해 나갔다.
#  - 최대한 효율성 좋은 코드를 작성하려고 노력했다.
#  - 코드를 작성하면서 주석과 설명을 상세하게 적어 목적성이 흐릿해지지 않았다.
#
# PROBLEM
#  - 아직 데이터 핸들링이 익숙하지 않아 반복문과 조건문을 남용하는 것 같다.
#  - pandas에 대한 개념을 제대로 활용하지 못한다.
#  - 전체적인 코드의 가독성이 떨어지고 지저분하다.
#
# TRY
#  - 딕셔너리의 활용 능력을 더욱 개선해야겠다.
#  - pandas 모듈에 대한 문서를 찾아 공부해봐야겠다.
#  - 완성하고 끝이 아닌 계속해서 코드를 다듬어봐야겠다.
