# %%
import os
import tensorflow as tf

# 저장된 경로에서 모델 불러오기
load_path = '/content/model'
best_model = tf.keras.models.load_model(load_path)

# %%
# 모델 구조 확인
best_model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_30 (Conv2D)          (None, 30, 30, 32)        896
#
#  average_pooling2d_30 (Aver  (None, 15, 15, 32)        0
#  agePooling2D)
#
#  batch_normalization_30 (Ba  (None, 15, 15, 32)        128
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 13, 13, 64)        18496
#
#  average_pooling2d_31 (Aver  (None, 6, 6, 64)          0
#  agePooling2D)
#
#  batch_normalization_31 (Ba  (None, 6, 6, 64)          256
#  tchNormalization)
#
#  flatten_15 (Flatten)        (None, 2304)              0
#
#  dense_30 (Dense)            (None, 256)               590080
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 612426 (2.34 MB)
# Trainable params: 612234 (2.34 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
# tflite 파일로 변환
converter = tf.lite.TFLiteConverter.from_keras_model(best_model)
tflite_model = converter.convert()

# %%
# 만들어진 tflite 파일 저장
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# 모델 서명 확인
interpreter = tf.lite.Interpreter(model_content=tflite_model)

signatures = interpreter.get_signature_list()
print(signatures)
# Out:
# {'serving_default': {'inputs': ['conv2d_30_input'], 'outputs': ['dense_31']}}

# %%
# 모델 서명 확인
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite
